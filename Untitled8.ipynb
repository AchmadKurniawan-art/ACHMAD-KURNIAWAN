# %%
a = float(input("masukkan nilai a: "))
b = float(input("masukkan nilai b: "))
c = float(input("masukkan nilai c: "))

if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("segitiga sama sisi")
    elif a == b or a == c or b == c:
        print("segitiga sama kaki")
    else:
        print("segitiga sembarang")
else:
  print("bukan segitiga")
# Out:
# masukkan nilai a: 2
# masukkan nilai b: 2
# masukkan nilai c: 2
# segitiga sama sisi

# %%
a = float(input("masukkan nilai a: "))
b = float(input("masukkan nilai b: "))
c = float(input("masukkan nilai c: "))

def determinan (a, b, c):
return (b ** 2 - 4 * a * c)
def akar(a, b, c):
  akar = determinan(a, b, c)
  if d > 0:
    d1 = (-b + d ** 0.5) / (2 * a)
    d2 = (-b - d ** 0.5) / (2 * a)
    print(d1, d2)
  elif d == 0:
  d = -b / 2 * a
  print(d)
  akar = hitung_akar(a, b, c)
  print()

# %%
import cmath

def hitung_akar_persamaan_kuadrat(a, b, c):
    # Menghitung determinan
    D = b**2 - 4*a*c
    print(f"Determinan (D) = {D}")

    # Menghitung akar-akar
    if D > 0:
        akar1 = (-b + cmath.sqrt(D)) / (2 * a)
        akar2 = (-b - cmath.sqrt(D)) / (2 * a)
        return akar1, akar2
    elif D == 0:
        akar = -b / (2 * a)
        return akar,
    else:
        akar1 = (-b + cmath.sqrt(D)) / (2 * a)
        akar2 = (-b - cmath.sqrt(D)) / (2 * a)
        return akar1, akar2

# Input dari pengguna
a = float(input("Masukkan koefisien a: "))
b = float(input("Masukkan koefisien b: "))
c = float(input("Masukkan koefisien c: "))

# Menghitung dan menampilkan hasil
akar = hitung_akar_persamaan_kuadrat(a, b, c)

print("Akar-akar persamaan kuadrat:")
for i, ak in enumerate(akar, start=1):
    print(f"Akar {i}: {ak}")
# Out:
# Masukkan koefisien a: 2
# Masukkan koefisien b: 3
# Masukkan koefisien c: 4
# Determinan (D) = -23.0
# Akar-akar persamaan kuadrat:
# Akar 1: (-0.75+1.1989578808281798j)
# Akar 2: (-0.75-1.1989578808281798j)
