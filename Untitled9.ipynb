# %%
import math

def hitung_determinant(a, b, c):
    return b**2 - 4*a*c

def akar_persamaan_kuadrat(a, b, c):
    determinant = hitung_determinant(a, b, c)

    if determinant > 0:
        # Dua akar real
        akar1 = (-b + cmath.sqrt(determinant)) / (2 * a)
        akar2 = (-b - cmath.sqrt(determinant)) / (2 * a)
        return akar1, akar2
    elif determinant == 0:
        # Satu akar real
        akar = -b / (2 * a)
        return akar,
    else:
        # Akar kompleks
        akar1 = (-b + cmath.sqrt(determinant)) / (2 * a)
        akar2 = (-b - cmath.sqrt(determinant)) / (2 * a)
        return akar1, akar2

# Input dari pengguna
print("Masukkan koefisien untuk persamaan kuadrat ax^2 + bx + c = 0")
a = float(input("Masukkan nilai a: "))
b = float(input("Masukkan nilai b: "))
c = float(input("Masukkan nilai c: "))

# Menghitung akar dan determinan
akar = akar_persamaan_kuadrat(a, b, c)
det = hitung_determinant(a, b, c)

# Menampilkan hasil
print(f"Determinant: {det}")
if len(akar) == 2:
    print(f"Akar-akar persamaan kuadrat: {akar[0]} dan {akar[1]}")
else:
    print(f"Akar persamaan kuadrat: {akar[0]}")
# Out:
# Masukkan koefisien untuk persamaan kuadrat ax^2 + bx + c = 0
# Masukkan nilai a: 30
# Masukkan nilai b: 30
# Masukkan nilai c: 4
# Determinant: 420.0
# Akar-akar persamaan kuadrat: (-0.1584349744680134+0j) dan (-0.8415650255319865+0j)
